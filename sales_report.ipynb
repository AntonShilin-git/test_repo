# %% [markdown]
# # Отчет по продажам для задачи ANALYTICS-1

# %%
import requests

# %%
data = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')

# %%
data.json()
# Out:
# {'Date': '2025-05-07T11:30:00+03:00',
#  'PreviousDate': '2025-05-06T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2025/05/06/daily_json.js',
#  'Timestamp': '2025-05-07T13:00:00+03:00',
#  'Valute': {'AUD': {'ID': 'R01010',
#    'NumCode': '036',
#    'CharCode': 'AUD',
#    'Nominal': 1,
#    'Name': 'Австралийский доллар',
#    'Value': 52.2463,
#    'Previous': 53.0719},
#   'AZN': {'ID': 'R01020A',
#    'NumCode': '944',
#    'CharCode': 'AZN',
#    'Nominal': 1,
#    'Name': 'Азербайджанский манат',
#    'Value': 47.6261,
#    'Previous': 48.1845},
#   'GBP': {'ID': 'R01035',
#    'NumCode': '826',
#    'CharCode': 'GBP',
#    'Nominal': 1,
#    'Name': 'Фунт стерлингов',
#    'Value': 107.8527,
#    'Previous': 108.9125},
#   'AMD': {'ID': 'R01060',
#    'NumCode': '051',
#    'CharCode': 'AMD',
#    'Nominal': 100,
#    'Name': 'Армянских драмов',
#    'Value': 20.7889,
#    'Previous': 21.0326},
#   'BYN': {'ID': 'R01090B',
#    'NumCode': '933',
# ...
